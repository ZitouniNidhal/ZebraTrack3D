# %% [markdown]
# # ZebraTrack3D Demo Notebook
#
# This notebook demonstrates loading prediction and ground‑truth CSV files, computing the extended metrics, and visualising a sample image sequence.

# %%
import pandas as pd
from src.utils.metrics import evaluate

# Paths – adjust if your data resides elsewhere
pred_path = "outputs/predictions/submission.csv"
gt_path = "data/processed/ground_truth.csv"

pred_df = pd.read_csv(pred_path)
gt_df = pd.read_csv(gt_path)

results = evaluate(pred_df, gt_df)
print(results)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from src.utils.metrics import evaluate
#       3
#       4 # Paths – adjust if your data resides elsewhere
#       5 pred_path = "outputs/predictions/submission.csv"
#
# ModuleNotFoundError: No module named 'src'

# %%
# Optional: visualise first frame with napari (if installed)
# import napari, tifffile
# img = tifffile.imread('data/train/images/seq_001.tif')[0]
# viewer = napari.Viewer()
# viewer.add_image(img)
